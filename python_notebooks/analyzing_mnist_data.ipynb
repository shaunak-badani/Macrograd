# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist_data = np.genfromtxt("../datasets/mnist_train.csv", delimiter=",")

# %%
image_1 = mnist_data[0, 1:].reshape(28, 28)
label_1 = mnist_data[0,0]

# %%
image_1.shape
# Out:
# (28, 28)

# %%
plt.imshow(image_1,  cmap="gray")
plt.title(label_1)
# Out:
# Text(0.5, 1.0, '5.0')

# %% [markdown]
# #

# %% [markdown]
# - This implies that the first column of the csv is the label
# - And the remaining 784 columns are the image values of the image rgb numbers.
